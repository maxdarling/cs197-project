# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ["0%", "25%", "50%", "75%", "100%"]
y_pos = np.arange(len(objects))

performance = [0.121566, 0.124542, 0.128396, 0.129913 ,0.132784]
                

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.ylabel('Time')
plt.xticks(y_pos, objects)
plt.title('LP lookups')

plt.show();

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ["0%", "25%", "50%", "75%", "100%"]
y_pos = np.arange(len(objects))

performance = [0.141827, 0.140655, 0.135359, 0.127771, 0.116006]


plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.ylabel('Time')
plt.xticks(y_pos, objects)
plt.title('CH lookups')

plt.show();
